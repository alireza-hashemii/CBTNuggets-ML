# %%
import seaborn as sns
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
import numpy as np

# %%
dataset = sns.load_dataset('mpg')
dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df = dataset.dropna()
x = df['horsepower'].values
y = df['mpg'].values

x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)
# Out:
# 313

# %%
x_test_reshaped = x_test.reshape(-1,1)
x_train_reshaped = x_train.reshape(-1,1)

model = LinearRegression()
model.fit(x_train_reshaped, y_train)
# Out:
# 313
# LinearRegression()

# %%
slope = model.coef_[0]
y_intercept = model.intercept_
print(f"Slope is {slope}\nintercept is {y_intercept}")
# Out:
# Slope is -0.16259724322918453
# intercept is 40.606097600118346

# %%
plt.scatter(x_train, y_train, label='Train Data')
plt.scatter(x_test, y_test, label='Test Data', color='r')
plt.plot(x_train, model.predict(x_train_reshaped),color='green', label=f'y_hat:{slope: .2f}x + {y_intercept: .2f}')
plt.xlabel('HorsePower')
plt.ylabel('Miles Per Gallon(MPG)')
plt.legend()
plt.show()

# %%
y_pred = model.predict(x_test_reshaped)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"""
Mean Absolute Error: {mae}
Mean Squared Error: {mse}
Root Mean Squared Error: {rmse}
""")
# Out:
# Mean Absolute Error: 3.782512710126959
# Mean Squared Error: 22.153237123863413
# Root Mean Squared Error: 4.706722545876633
